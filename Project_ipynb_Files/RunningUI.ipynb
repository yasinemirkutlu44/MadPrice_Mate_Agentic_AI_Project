# %% [markdown]
# # Agentic AI UI (Productionised)

# %%
import gradio as gr
from Agents_Folder.Deal_Scraper import Opportunity, Deal
from Agents_Folder.deal_agent_framework import DealAgentFramework
DealAgentFramework.reset_memory()

# %%
import logging
root = logging.getLogger()
root.setLevel(logging.INFO)

# %%
# !uv run MadPrice_Mate.py
# Out:
# * Running on local URL:  http://127.0.0.1:7860
# * To create a public link, set `share=True` in `launch()`.
# [2026-01-20 18:06:31 +0300] [Agents] [INFO] Anonymized telemetry enabled. See                     https://docs.trychroma.com/telemetry for more information.
# [2026-01-20 18:06:31 +0300] [Agents] [INFO] Anonymized telemetry enabled. See                     https://docs.trychroma.com/telemetry for more information.
# [2026-01-20 18:06:31 +0300] [Agents] [INFO] Anonymized telemetry enabled. See                     https://docs.trychroma.com/telemetry for more information.
# [2026-01-20 18:06:31 +0300] [Agents] [INFO] Anonymized telemetry enabled. See                     https://docs.trychroma.com/telemetry for more information.
# [2026-01-20 18:06:31 +0300] [Agents] [INFO] [Agent Framework] Initializing Agent Framework
# [2026-01-20 18:06:31 +0300] [Agents] [INFO] [Agent Framework] Initializing Agent Framework
# ...
