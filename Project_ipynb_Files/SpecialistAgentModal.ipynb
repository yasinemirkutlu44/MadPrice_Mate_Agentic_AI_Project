# %% [markdown]
# # MadPrice Mate

# %% [markdown]
# # Integrating Modal for LLM Productionization

# %% [markdown]
# # Libraries Import

# %%
# imports
# 1) make your folder importable
import os
import locale
import modal
from Agents_Folder.preprocessor import Preprocessor
from dotenv import load_dotenv
load_dotenv(override=True)
# Out:
# True

# %%
# To confirm your computer can display special characters, ensure it uses UTF-8 output.

print(locale.getpreferredencoding())
# Out:
# UTF-8

# %% [markdown]
# # Defining the Modal Credentials

# %%
# Modal credentials activated using UV environment variables. --- IGNORE ---

# %% [markdown]
# # Running Code in local and in the Cloud

# %%
from hello import app_instance, hello_instance, hi_instance_cloud

# %% [markdown]
# # Local

# %%
with app_instance.run():
    response = hello_instance.local()
response
# Out:
# 'Hello from Istanbul, Istanbul, TR!'

# %% [markdown]
# # Cloud

# %%
with app_instance.run():
    response = hi_instance_cloud.remote()
response
# Out:
# 'Hi from Phoenix, Arizona, US!'
